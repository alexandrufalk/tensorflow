# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrufalk/tensorflow/blob/Master/01_Neural_Network_Regression_tensorflow_exercise_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
#https://drive.google.com/file/d/1qxFAM-k-L4tBZzYyzemfryelJ0F0nAa7/view?usp=drivesdk
# Out:
#  00_tensorflow_fundamentals.ipynb
# '01_Neural_Network_Regression_tensorflow_exercise .ipynb'
#  01_Neural_Network_Regression_tensorflow.ipynb
#  honey_purity_dataset.csv

# %%
# File path of the CSV file in Google Drive
file_id = '1qxFAM-k-L4tBZzYyzemfryelJ0F0nAa7'
#file_path = f'/content/drive/My Drive/{file_id}'
file_path = '/content/drive/My Drive/Colab Notebooks/honey_purity_dataset.csv'


# https://drive.google.com/file/d/1qxFAM-k-L4tBZzYyzemfryelJ0F0nAa7/view?usp=drive_link
#honey_purity_dataset.csv

# Import necessary libraries
import pandas as pd

# Read CSV file into a DataFrame
df = pd.read_csv(file_path)

df.head()
# Out:
#      CS  Density     WC    pH    EC      F      G Pollen_analysis  Viscosity  \
# 0  2.81     1.75  23.04  6.29  0.76  39.02  33.63       Blueberry    4844.50
# 1  9.47     1.82  17.50  7.20  0.71  38.15  34.41         Alfalfa    6689.02
# 2  4.61     1.84  23.72  7.31  0.80  27.47  34.36        Chestnut    6883.60
# 3  1.77     1.40  16.61  4.01  0.78  31.52  28.15       Blueberry    7167.56
# 4  6.11     1.25  19.63  4.82  0.90  29.65  42.52         Alfalfa    5125.44
#
#    Purity   Price
# 0    0.68  645.24
# 1    0.89  385.85
# 2    0.66  639.64
# 3    1.00  946.46
# 4    1.00  432.62
